# %% [markdown]
# # Importing needed libraries

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %% [markdown]
# # Importing "train.csv" and "test.csv" to data frame

# %%
train = pd.read_csv('Files/train.csv')
test = pd.read_csv('Files/test.csv')

# %% [markdown]
# # Adding the new feature called 'none' if all toxic_kind features value is 0. so if it is nice comment, 'none'=1, else =0

# %%
label_cols = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
train['none'] = 1 - train[label_cols].max(axis=1)

# %% [markdown]
# # Fill the null cell with "unknown" values for both "train" and "test" data frame

# %%
train['comment_text'].fillna('unknown', inplace=True) 
test['comment_text'].fillna('unknown', inplace=True)

# %% [markdown]
# # build the TF-IDF model.

# %%
import re, string

re_tok = re.compile(f'([{string.punctuation}“”¨«»®´·º½¾¿¡§£₤‘’])')
# this will split s by symbols create a list of string

def tokenize(s): 
    return re_tok.sub(r' \1 ', s).split()

# Tfid Text Vectorization
vec = TfidfVectorizer(ngram_range=(1,2), tokenizer=tokenize, min_df=3, max_df=0.9, strip_accents='unicode',
                     use_idf=1, smooth_idf=1, sublinear_tf=1)

# train_term_doc is the crs_matrix -> compress row matrix with 1 row and n columns.
train_term_doc = vec.fit_transform(train['comment_text'])


# the same as train_term_doc (X_test crs_matrix)
test_term_doc = vec.transform(test['comment_text'])

# %% [markdown]
# # Checking type and values of train_term_doc and test_term_doc

# %%
print(type(train_term_doc))
print(train_term_doc[0])

print(type(test_term_doc))
print(test_term_doc[0])
# Out:
# <class 'scipy.sparse.csr.csr_matrix'>
#   (0, 22653)	0.11225676787445103
#   (0, 35387)	0.11974557970427763
#   (0, 22697)	0.11607450613653243
#   (0, 33939)	0.11986525556711788
#   (0, 22587)	0.11805863895962679
#   (0, 37321)	0.11570798175128982
#   (0, 22797)	0.11408215406028954
#   (0, 259012)	0.07853618304798789
#   (0, 312720)	0.16402564821709473
#   (0, 231196)	0.16669852085274084
#   (0, 7513)	0.050569258726441545
#   (0, 193977)	0.04236000551960604
#   (0, 331780)	0.0907489579883015
#   (0, 280170)	0.13515323124110395
#   (0, 352591)	0.05515959489565422
#   (0, 368268)	0.07465956912509807
#   (0, 169974)	0.05914892960828189
#   (0, 354240)	0.1326518250254369
#   (0, 368343)	0.09379933899140203
#   (0, 309415)	0.08032576894305525
#   (0, 351141)	0.11683624691357157
#   (0, 141577)	0.046644903958262866
#   (0, 288508)	0.09175569723097404
#   (0, 68485)	0.10174180819931931
#   (0, 23017)	0.06149535138131129
#   :	:
#   (0, 172411)	0.11169554291171112
#   (0, 335723)	0.04728814119210447
#   (0, 268787)	0.031841956504032994
#   (0, 115362)	0.12586966621676254
#   (0, 216481)	0.04369540773786537
#   (0, 11880)	0.020422857416240035
#   (0, 395665)	0.13995024181834184
#   (0, 350338)	0.06000137354577802
#   (0, 6837)	0.053085714729024396
#   (0, 405772)	0.10167216335676989
#   (0, 372640)	0.04649183348345615
#   (0, 41026)	0.03476653974063545
#   (0, 313199)	0.0721378910588976
#   (0, 404947)	0.053984137023003295
#   (0, 158369)	0.09331994330310292
#   (0, 239747)	0.14144239767301586
#   (0, 181782)	0.12307662723794742
#   (0, 394106)	0.08584686131575688
#   (0, 247352)	0.04009335280681195
#   (0, 389638)	0.06447039503637214
#   (0, 231608)	0.05824510929741852
#   (0, 146170)	0.05958322312749654
#   (0, 359013)	0.04305623955927827
#   (0, 409552)	0.050464296356772576
#   (0, 155788)	0.08387304169167062
# <class 'scipy.sparse.csr.csr_matrix'>
#   (0, 420846)	0.06264597170601387
#   (0, 420598)	0.12046557529503839
#   (0, 419855)	0.08406061492846077
#   (0, 419195)	0.07118469052073481
#   (0, 419091)	0.04918343739622535
#   (0, 419086)	0.05822201127745243
#   (0, 418956)	0.09266871281466525
#   (0, 417514)	0.05830405747158206
#   (0, 414137)	0.07101580171802878
#   (0, 412674)	0.031147011148436904
#   (0, 408257)	0.1453374704535069
#   (0, 408230)	0.1274162350468248
#   (0, 406593)	0.12286918852894226
#   (0, 406576)	0.0950323209276682
#   (0, 401053)	0.06049917274467092
#   (0, 401009)	0.03384830120858831
#   (0, 392701)	0.09067472490403695
#   (0, 392204)	0.07659721855285131
#   (0, 391901)	0.04381027268186382
#   (0, 387216)	0.1321772604563056
#   (0, 383506)	0.07192436262531807
#   (0, 383498)	0.052971053952804166
#   (0, 380850)	0.1321772604563056
#   (0, 378627)	0.01946717984975152
#   (0, 377726)	0.0651213766205708
#   :	:
#   (0, 139705)	0.13047051217744302
#   (0, 129670)	0.09679625778378657
#   (0, 100964)	0.09018708331193309
#   (0, 99600)	0.09513256948622296
#   (0, 96108)	0.1371002868040914
#   (0, 92646)	0.13414755674626097
#   (0, 88228)	0.027955791229067637
#   (0, 81990)	0.12640015578557745
#   (0, 81920)	0.07669198544253465
#   (0, 66688)	0.08507311441853056
#   (0, 64078)	0.045149148737223005
#   (0, 49138)	0.036132372323427905
#   (0, 43849)	0.13525970359802114
#   (0, 43432)	0.021227731323952826
#   (0, 25098)	0.1430071045587047
#   (0, 24925)	0.03182346379066739
#   (0, 24568)	0.1410368082687493
#   (0, 24120)	0.10571325120166293
#   (0, 23017)	0.05361522567020669
#   (0, 22397)	0.10331522520919251
#   (0, 22395)	0.07394251230585176
#   (0, 22383)	0.04893079613529389
#   (0, 11880)	0.017805835475475172
#   (0, 7500)	0.05330624248520767
#   (0, 6837)	0.02205419997807093

# %% [markdown]
# # Checking vocabulary after extracting words from comment_text

# %%
vec.vocabulary_
# Out:
# {'explanation': 155788,
#  'why': 409552,
#  'the': 359013,
#  'edits': 146170,
#  'made': 231608,
#  'under': 389638,
#  'my': 247352,
#  'username': 394106,
#  'hardcore': 181782,
#  'metallica': 239747,
#  'fan': 158369,
#  'were': 404947,
#  'reverted': 313199,
#  '?': 41026,
#  'they': 372640,
#  'weren': 405772,
#  "'": 6837,
#  't': 350338,
#  'vandalisms': 395665,
#  ',': 11880,
#  'just': 216481,
#  'closure': 115362,
#  'on': 268787,
#  'some': 335723,
#  'gas': 172411,
#  'after': 55748,
#  'i': 193972,
#  'voted': 399511,
#  'at': 82724,
#  'new': 252275,
#  'york': 419031,
#  'dolls': 141447,
#  'fac': 156826,
#  '.': 22383,
#  'and': 64078,
#  'please': 288402,
#  'don': 141575,
#  'remove': 309308,
#  'template': 354198,
#  'from': 168981,
#  'talk': 352461,
#  'page': 279728,
#  'since': 331671,
#  'm': 230844,
#  'retired': 312707,
#  'now': 259003,
#  '89': 37316,
#  '205': 33937,
#  '38': 35380,
#  '27': 34568,
#  'explanation why': 155833,
#  'why the': 409695,
#  'the edits': 362169,
#  'edits made': 146265,
#  'made under': 231793,
#  'under my': 389753,
#  'my username': 248742,
#  'hardcore metallica': 181789,
#  'metallica fan': 239750,
#  'were reverted': 405581,
#  'reverted ?': 313213,
#  '? they': 41860,
#  'they weren': 373297,
#  "weren '": 405773,
#  "' t": 7898,
#  'vandalisms ,': 395666,
#  ', just': 15162,
#  'closure on': 115367,
#  'on some': 270094,
#  'after i': 55864,
#  'i voted': 195305,
#  'voted at': 399518,
#  'at new': 83084,
#  'new york': 252737,
#  'fac .': 156831,
#  '. and': 23017,
#  'and please': 68485,
#  'please don': 288508,
#  "don '": 141577,
#  't remove': 351141,
#  'remove the': 309415,
#  'the template': 368343,
#  'template from': 354240,
#  'from the': 169974,
#  'the talk': 368268,
#  'talk page': 352591,
#  'page since': 280170,
#  'since i': 331780,
#  "i '": 193977,
#  "' m": 7513,
#  'm retired': 231196,
#  'retired now': 312720,
#  'now .': 259012,
#  '. 89': 22797,
#  '89 .': 37321,
#  '. 205': 22587,
#  '205 .': 33939,
#  '. 38': 22697,
#  '38 .': 35387,
#  '. 27': 22653,
#  'd': 129431,
#  'aww': 85484,
#  '!': 0,
#  'he': 184680,
#  'matches': 235490,
#  'this': 374078,
#  'background': 85971,
#  'colour': 116603,
#  'seemingly': 325135,
#  'stuck': 345592,
#  'with': 412674,
#  'thanks': 356042,
#  '(': 8097,
#  ')': 10256,
#  '21': 34004,
#  ':': 37606,
#  '51': 36216,
#  'january': 214205,
#  '11': 30646,
#  '2016': 33917,
#  'utc': 394814,
#  "d '": 129436,
#  '! he': 333,
#  'this background': 374255,
#  'stuck with': 345607,
#  'with .': 412686,
#  '. thanks': 27178,
#  'thanks .': 356051,
#  '. (': 22391,
#  '( talk': 9949,
#  'talk )': 352469,
#  ') 21': 10306,
#  '21 :': 34017,
#  ': 51': 37772,
#  '51 ,': 36221,
#  ', january': 15068,
#  'january 11': 214214,
#  '11 ,': 30655,
#  ', 2016': 12097,
#  '2016 (': 33918,
#  '( utc': 10094,
#  'utc )': 394817,
#  'hey': 187847,
#  'man': 233466,
#  'really': 304292,
#  'not': 255826,
#  'trying': 387039,
#  'to': 378627,
#  'edit': 145112,
#  'war': 400388,
#  'it': 211563,
#  's': 317288,
#  'that': 356156,
#  'guy': 179806,
#  'is': 208006,
#  'constantly': 121628,
#  'removing': 309597,
#  'relevant': 308430,
#  'information': 203633,
#  'talking': 352721,
#  'me': 236697,
#  'through': 377033,
#  'instead': 204825,
#  'of': 261425,
#  'seems': 325142,
#  'care': 107148,
#  'more': 243590,
#  'about': 49138,
#  'formatting': 167110,
#  'than': 355526,
#  'actual': 52559,
#  'info': 203422,
#  'hey man': 187906,
#  'man ,': 233472,
#  ', i': 14810,
#  'm really': 231182,
#  'really not': 304551,
#  'not trying': 257823,
#  'trying to': 387063,
#  'to edit': 379997,
#  'edit war': 145361,
#  'war .': 400398,
#  '. it': 25086,
#  "it '": 211568,
#  "' s": 7786,
#  's just': 318526,
#  'just that': 217250,
#  'that this': 358657,
#  'this guy': 374786,
#  'guy is': 179854,
#  'is constantly': 208557,
#  'constantly removing': 121650,
#  'removing relevant': 309655,
#  'relevant information': 308488,
#  'information and': 203662,
#  'and talking': 69891,
#  'talking to': 352751,
#  'to me': 381060,
#  'me through': 237158,
#  'through edits': 377075,
#  'edits instead': 146257,
#  'instead of': 204862,
#  'of my': 264912,
#  'my talk': 248653,
#  'page .': 279739,
#  '. he': 24792,
#  'he seems': 185252,
#  'seems to': 325261,
#  'to care': 379316,
#  'care more': 107184,
#  'more about': 243605,
#  'about the': 49992,
#  'the formatting': 362836,
#  'formatting than': 167133,
#  'than the': 355924,
#  'the actual': 359374,
#  'actual info': 52613,
#  'info .': 203431,
#  '"': 750,
#  'can': 105545,
#  'make': 232671,
#  'any': 72212,
#  'real': 303940,
#  'suggestions': 347758,
#  'improvement': 198287,
#  '-': 18304,
#  'wondered': 414936,
#  'if': 196081,
#  'section': 324241,
#  'statistics': 342978,
#  'should': 329236,
#  'be': 88228,
#  'later': 221980,
#  'or': 273193,
#  'a': 43432,
#  'subsection': 346590,
#  'types': 388311,
#  'accidents': 51167,
#  'think': 373678,
#  'references': 306814,
#  'may': 236079,
#  'need': 250878,
#  'tidying': 377546,
#  'so': 334147,
#  'are': 75604,
#  'all': 58008,
#  'in': 198396,
#  'exact': 154028,
#  'same': 320561,
#  'format': 167027,
#  'ie': 196053,
#  'date': 130473,
#  'etc': 151698,
#  'do': 140353,
#  'no': 253913,
#  'one': 270529,
#  'else': 147664,
#  'does': 140992,
#  'first': 162124,
#  'you': 419086,
#  'have': 183084,
#  'preferences': 292834,
#  'for': 164351,
#  'style': 346068,
#  'want': 400181,
#  'yourself': 423139,
#  'let': 224416,
#  'know': 219624,
#  'there': 371692,
#  'appears': 74213,
#  'backlog': 86038,
#  'articles': 79539,
#  'review': 313440,
#  'guess': 179210,
#  'delay': 133001,
#  'until': 391637,
#  'reviewer': 313604,
#  'turns': 387487,
#  'up': 391901,
#  'listed': 227214,
#  'form': 166930,
#  'eg': 146767,
#  'wikipedia': 410425,
#  'good': 176371,
#  '_': 42609,
#  'article': 78790,
#  'nominations': 255167,
#  '#': 6053,
#  'transport': 385484,
#  '" more': 3818,
#  'more i': 243988,
#  'i can': 194172,
#  "can '": 105548,
#  't make': 350918,
#  'make any': 232697,
#  'any real': 72870,
#  'suggestions on': 347787,
#  'improvement -': 198293,
#  '- i': 20242,
#  'i wondered': 195360,
#  'wondered if': 414941,
#  'if the': 196320,
#  'the section': 367404,
#  'should be': 329289,
#  'be later': 89296,
#  'later on': 222035,
#  'on ,': 268796,
#  ', or': 16078,
#  'or a': 273245,
#  'a subsection': 47980,
#  'subsection of': 346600,
#  'of "': 261427,
#  '" "': 752,
#  '" types': 5607,
#  'types of': 388326,
#  'of accidents': 261633,
#  'accidents "': 51168,
#  '" -': 763,
#  'i think': 195212,
#  'think the': 373847,
#  'the references': 366819,
#  'references may': 306883,
#  'may need': 236283,
#  'need tidying': 251006,
#  'so that': 334721,
#  'that they': 358650,
#  'they are': 372692,
#  'are all': 75712,
#  'all in': 58360,
#  'in the': 200851,
#  'the exact': 362428,
#  'exact same': 154065,
#  'same format': 320705,
#  'date format': 130503,
#  'format etc': 167047,
#  'etc .': 151705,
#  '. i': 24925,
#  'can do': 105745,
#  'do that': 140640,
#  'that later': 357571,
#  ', if': 14835,
#  'if no': 196251,
#  'no -': 253921,
#  '- one': 20959,
#  'one else': 270723,
#  'else does': 147708,
#  'first -': 162131,
#  '- if': 20255,
#  'if you': 196365,
#  'you have': 419874,
#  'have any': 183179,
#  'preferences for': 292841,
#  'for formatting': 165146,
#  'style on': 346123,
#  'on references': 269957,
#  'references or': 306894,
#  'or want': 275072,
#  'want to': 400278,
#  'to do': 379919,
#  'do it': 140509,
#  'it yourself': 212813,
#  'yourself please': 423211,
#  'please let': 288587,
#  'let me': 224444,
#  'me know': 236948,
#  'know .': 219634,
#  '. there': 27201,
#  'there appears': 371732,
#  'appears to': 74255,
#  'to be': 379120,
#  'be a': 88259,
#  'a backlog': 43580,
#  'backlog on': 86048,
#  'on articles': 268968,
#  'articles for': 79644,
#  'for review': 165965,
#  'review so': 313531,
#  'so i': 334448,
#  'i guess': 194508,
#  'guess there': 179257,
#  'there may': 371818,
#  'may be': 236174,
#  'a delay': 44631,
#  'until a': 391664,
#  'a reviewer': 47315,
#  'turns up': 387494,
#  'up .': 391912,
#  's listed': 318610,
#  'listed in': 227248,
#  'the relevant': 366877,
#  'wikipedia :': 410443,
#  ': good': 38634,
#  'good _': 176386,
#  '_ article': 42714,
#  'article _': 78821,
#  '_ nominations': 43114,
#  'sir': 332248,
#  'hero': 187688,
#  'chance': 110048,
#  'remember': 309090,
#  'what': 406022,
#  'you ,': 419095,
#  ', sir': 17146,
#  'sir ,': 332253,
#  ', are': 12619,
#  'are my': 76775,
#  'my hero': 247992,
#  'hero .': 187693,
#  '. any': 23049,
#  'any chance': 72335,
#  'chance you': 110075,
#  'you remember': 420520,
#  'remember what': 309152,
#  'what page': 406323,
#  'page that': 280214,
#  "that '": 356161,
#  's on': 318856,
#  'on ?': 268865,
#  'congratulations': 120633,
#  'as': 80008,
#  'well': 404607,
#  'use': 393231,
#  'tools': 383832,
#  '·': 424593,
#  '" congratulations': 1837,
#  'congratulations from': 120641,
#  'from me': 169642,
#  'me as': 236758,
#  'as well': 81355,
#  'well ,': 404613,
#  ', use': 17899,
#  'use the': 393448,
#  'the tools': 368524,
#  'tools well': 383856,
#  'well .': 404615,
#  '. ·': 27838,
#  '· talk': 424643,
#  'talk "': 352463,
#  'cocksucker': 115793,
#  'before': 92051,
#  'piss': 287371,
#  'around': 78384,
#  'work': 415402,
#  'before you': 92283,
#  'you piss': 420336,
#  'around on': 78480,
#  'on my': 269730,
#  'my work': 248811,
#  'your': 421116,
#  'vandalism': 395515,
#  'matt': 235809,
#  'has': 182117,
#  'been': 91037,
#  'again': 56057,
#  'will': 411433,
#  'banned': 87025,
#  'your vandalism': 422992,
#  'vandalism to': 395639,
#  'to the': 382543,
#  'the matt': 364833,
#  'article has': 79081,
#  'has been': 182218,
#  'been reverted': 91778,
#  'reverted .': 313206,
#  '. please': 26170,
#  't do': 350646,
#  'it again': 211623,
#  'again ,': 56065,
#  'or you': 275155,
#  'you will': 421002,
#  'will be': 411512,
#  'be banned': 88447,
#  'banned .': 87032,
#  'sorry': 337847,
#  'word': 415100,
#  'nonsense': 255324,
#  'was': 401009,
#  'offensive': 267468,
#  'anyway': 73586,
#  'intending': 205379,
#  'write': 417099,
#  'anything': 73411,
#  'wow': 416857,
#  'would': 416310,
#  'jump': 216254,
#  'merely': 239088,
#  'requesting': 311039,
#  'encyclopedic': 148807,
#  'school': 322610,
#  'reference': 306612,
#  'selective': 325517,
#  'breeding': 100142,
#  'but': 102243,
#  'almost': 59288,
#  'stub': 345508,
#  'points': 289379,
#  'animal': 71039,
#  'which': 407273,
#  'short': 329006,
#  'messy': 239632,
#  'gives': 175145,
#  'must': 247065,
#  'someone': 336851,
#  'expertise': 155554,
#  'eugenics': 151985,
#  '93': 37479,
#  '161': 31447,
#  '107': 30609,
#  '169': 31507,
#  'sorry if': 337880,
#  'the word': 369375,
#  "word '": 415103,
#  "' nonsense": 7601,
#  "nonsense '": 255327,
#  "' was": 8019,
#  'was offensive': 401968,
#  'offensive to': 267508,
#  'to you': 382938,
#  'you .': 419097,
#  '. anyway': 23057,
#  'anyway ,': 73591,
#  'm not': 231122,
#  'not intending': 256850,
#  'intending to': 205381,
#  'to write': 382917,
#  'write anything': 417118,
#  'anything in': 73483,
#  'the article': 359813,
#  'article (': 78796,
#  '( wow': 10178,
#  'they would': 373312,
#  'would jump': 416568,
#  'jump on': 216266,
#  'on me': 269682,
#  'me for': 236880,
#  'for vandalism': 166347,
#  'vandalism )': 395521,
#  ') ,': 10267,
#  'm merely': 231106,
#  'requesting that': 311054,
#  'that it': 357461,
#  'it be': 211700,
#  'be more': 89416,
#  'more encyclopedic': 243872,
#  'so one': 334567,
#  'one can': 270628,
#  'can use': 106184,
#  'use it': 393353,
#  'it for': 212022,
#  'for school': 166007,
#  'school as': 322633,
#  'as a': 80054,
#  'a reference': 47186,
#  'reference .': 306621,
#  'i have': 194531,
#  'have been': 183233,
#  'been to': 91921,
#  'the selective': 367426,
#  'selective breeding': 325522,
#  'page but': 279856,
#  'but it': 102566,
#  's almost': 317429,
#  'almost a': 59304,
#  'a stub': 47951,
#  'stub .': 345515,
#  'it points': 212383,
#  'points to': 289438,
#  "to '": 378632,
#  "' which": 8035,
#  'which is': 407582,
#  'is a': 208078,
#  'a short': 47601,
#  'article that': 79435,
#  'that gives': 357220,
#  'gives you': 175186,
#  'you no': 420228,
#  'no info': 254356,
#  'there must': 371822,
#  'must be': 247096,
#  'be someone': 89961,
#  'someone around': 336878,
#  'around with': 78523,
#  'with expertise': 413167,
#  'expertise in': 155561,
#  '? 93': 41166,
#  '93 .': 37484,
#  '. 161': 22494,
#  '161 .': 31450,
#  '. 107': 22431,
#  '107 .': 30613,
#  '. 169': 22502,
#  'alignment': 57959,
#  'subject': 346274,
#  'contrary': 122915,
#  'those': 375935,
#  'dulithgow': 143464,
#  'on this': 270216,
#  'this subject': 375563,
#  'subject and': 346290,
#  'and which': 70537,
#  'which are': 407324,
#  'are contrary': 76019,
#  'contrary to': 122931,
#  'to those': 382562,
#  'those of': 376155,
#  'fair': 157596,
#  'rationale': 302744,
#  'image': 196944,
#  'jpg': 215853,
#  'uploading': 392480,
#  'notice': 258539,
#  'specifies': 339991,
#  'being': 92648,
#  'used': 393490,
#  'its': 213005,
#  'constitutes': 121701,
#  'addition': 53645,
#  'boilerplate': 98024,
#  'also': 59868,
#  'out': 277829,
#  'description': 134768,
#  'specific': 339694,
#  'using': 394448,
#  'each': 144083,
#  'consistent': 121482,
#  'go': 175553,
#  'include': 201544,
#  'uploaded': 392431,
#  'other': 276194,
#  'media': 237817,
#  'consider': 121120,
#  'checking': 111286,
#  'specified': 339976,
#  'pages': 280318,
#  'too': 383498,
#  'find': 161507,
#  'list': 227053,
#  'edited': 145406,
#  'by': 103114,
#  'clicking': 114970,
#  'contributions': 123167,
#  'link': 226588,
#  'located': 228623,
#  'very': 397280,
#  'top': 383883,
#  'when': 406661,
#  'logged': 228832,
#  'then': 370973,
#  'selecting': 325498,
#  'dropdown': 143066,
#  'box': 99440,
#  'note': 258222,
#  'images': 197118,
#  '4': 35555,
#  '2006': 33463,
#  'lacking': 220854,
#  'such': 346965,
#  'an': 62496,
#  'deleted': 133165,
#  'week': 404247,
#  'described': 134691,
#  'criteria': 127487,
#  'speedy': 340208,
#  'deletion': 133449,
#  'questions': 300421,
#  'ask': 81601,
#  'them': 370559,
#  'copyright': 124256,
#  'thank': 355999,
#  '•': 425549,
#  'contribs': 122973,
#  'unspecified': 391546,
#  'source': 338175,
#  'noticed': 258653,
#  'file': 160922,
#  'currently': 128908,
#  'doesn': 141169,
#  'specify': 339995,
#  'who': 408396,
#  'created': 126763,
#  'content': 122228,
#  'status': 343045,
#  'unclear': 389471,
#  'did': 136316,
#  'create': 126702,
#  'owner': 279420,
#  'obtained': 260730,
#  'website': 404039,
#  'taken': 352182,
#  'together': 383094,
#  'restatement': 312260,
#  'terms': 354772,
#  'usually': 394684,
#  'sufficient': 347493,
#  'however': 192852,
#  'holder': 191138,
#  'different': 136853,
#  'publisher': 298734,
#  'their': 369548,
#  'acknowledged': 51867,
#  'adding': 53516,
#  'add': 53149,
#  'proper': 296713,
#  'licensing': 225173,
#  'tag': 351729,
#  'already': 59587,
#  '/': 27977,
#  'took': 383722,
#  'picture': 286857,
#  'audio': 84182,
#  'video': 398076,
#  'release': 308276,
#  'gfdl': 174515,
#  'believe': 93423,
#  'meets': 238267,
#  'tags': 351894,
#  'see': 324653,
#  'full': 170730,
#  'files': 161014,
#  'tagged': 351833,
#  'following': 163878,
#  '[': 42081,
#  ']': 42364,
#  'unsourced': 391502,
#  'untagged': 391621,
#  'copyrighted': 124356,
#  'non': 255210,
#  'free': 168310,
#  'license': 225095,
#  'per': 284255,
#  '48': 35912,
#  'hours': 192380,
#  '" fair': 2546,
#  'fair use': 157654,
#  'use rationale': 393413,
#  'rationale for': 302760,
#  'for image': 165300,
#  'image :': 196955,
#  '. jpg': 25179,
#  'jpg thanks': 215896,
#  'thanks for': 356077,
#  'for uploading': 166327,
#  'uploading image': 392489,
#  'jpg .': 215862,
#  'i notice': 194756,
#  'notice the': 258597,
#  'the image': 363719,
#  'image page': 197049,
#  'page specifies': 280188,
#  'specifies that': 339993,
#  'that the': 358640,
#  'image is': 197022,
#  'is being': 208323,
#  'being used': 93275,
#  'used under': 393640,
#  'under fair': 389714,
#  'use but': 393280,
#  'but there': 102848,
#  'there is': 371806,
#  'is no': 209675,
#  'no explanation': 254241,
#  'explanation or': 155821,
#  'or rationale': 274606,
#  'rationale as': 302755,
#  'as to': 81269,
#  'to why': 382858,
#  'why its': 409644,
#  'its use': 213628,
#  'use in': 393347,
#  'in wikipedia': 201092,
#  'wikipedia articles': 410495,
#  'articles constitutes': 79606,
#  'constitutes fair': 121707,
#  'use .': 393240,
#  '. in': 24978,
#  'in addition': 198675,
#  'addition to': 53673,
#  'the boilerplate': 360328,
#  'boilerplate fair': 98026,
#  'use template': 393443,
#  'template ,': 354204,
#  ', you': 18252,
#  'you must': 420199,
#  'must also': 247084,
#  'also write': 60681,
#  'write out': 417162,
#  'out on': 277974,
#  'on the': 270198,
#  'image description': 196992,
#  'description page': 134798,
#  'page a': 279792,
#  'a specific': 47800,
#  'specific explanation': 339750,
#  'for why': 166422,
#  'why using': 409709,
#  'using this': 394594,
#  'this image': 374846,
#  'image in': 197019,
#  'in each': 199344,
#  'each article': 144093,
#  'article is': 79125,
#  'is consistent': 208553,
#  'consistent with': 121498,
#  'with fair': 413180,
#  'please go': 288551,
#  'go to': 175733,
#  'page and': 279813,
#  'and edit': 66063,
#  'edit it': 145242,
#  'it to': 212691,
#  'to include': 380638,
#  'include a': 201553,
#  'a fair': 44973,
#  'rationale .': 302749,
#  '. if': 24943,
#  'have uploaded': 184305,
#  'uploaded other': 392459,
#  'other fair': 276495,
#  'use media': 393371,
#  'media ,': 237822,
#  ', consider': 13423,
#  'consider checking': 121146,
#  'checking that': 111312,
#  'that you': 358933,
#  'have specified': 184182,
#  'specified the': 339986,
#  'the fair': 362557,
#  'rationale on': 302768,
#  'on those': 270218,
#  'those pages': 376170,
#  'pages too': 280461,
#  'too .': 383506,
#  '. you': 27792,
#  'you can': 419370,
#  'can find': 105802,
#  'find a': 161521,
#  'a list': 45883,
#  'list of': 227150,
#  "of '": 261430,
#  "' image": 7393,
#  "image '": 196948,
#  "' pages": 7650,
#  'pages you': 280491,
#  'have edited': 183461,
#  'edited by': 145432,
#  'by clicking': 103433,
#  'clicking on': 114976,
#  'the "': 359015,
#  '" my': 3864,
#  'my contributions': 247682,
#  'contributions "': 123169,
#  '" link': 3535,
#  'link (': 226592,
#  '( it': 9182,
#  'it is': 212161,
#  'is located': 209494,
#  'located at': 228631,
#  'at the': 83229,
#  'the very': 369022,
#  'very top': 397745,
#  'top of': 383938,
#  'of any': 261839,
#  'any wikipedia': 73101,
#  'wikipedia page': 410775,
#  'page when': 280273,
#  'when you': 406948,
#  'you are': 419231,
#  'are logged': 76681,
#  'logged in': 228839,
#  'in )': 198404,
#  ', and': 12526,
#  'and then': 69976,
#  'then selecting': 371347,
#  'selecting "': 325499,
#  '" image': 3105,
#  'image "': 196946,
#  '" from': 2725,
#  'the dropdown': 362069,
#  'dropdown box': 143067,
#  'box .': 99449,
#  '. note': 25878,
#  'note that': 258288,
#  'that any': 356347,
#  'any fair': 72521,
#  'use images': 393346,
#  'images uploaded': 197220,
#  'uploaded after': 392438,
#  'after 4': 55775,
#  '4 may': 35623,
#  'may ,': 236084,
#  ', 2006': 12086,
#  '2006 ,': 33468,
#  'and lacking': 67465,
#  'lacking such': 220868,
#  'such an': 346990,
#  'an explanation': 63164,
#  'explanation will': 155834,
#  'be deleted': 88741,
#  'deleted one': 133258,
#  'one week': 271213,
#  'week after': 404260,
#  'after they': 55971,
#  'they have': 372927,
#  'been uploaded': 91963,
#  'uploaded ,': 392433,
#  ', as': 12658,
#  'as described': 80337,
#  'described on': 134712,
#  'on criteria': 269178,
#  'criteria for': 127509,
#  'for speedy': 166129,
#  'speedy deletion': 340226,
#  'deletion .': 133458,
#  'any questions': 72858,
#  'questions please': 300481,
#  'please ask': 288442,
#  'ask them': 81673,
#  'them at': 370609,
#  'the media': 364873,
#  'media copyright': 237849,
#  'copyright questions': 124323,
#  'questions page': 300480,
#  '. thank': 27175,
#  'thank you': 356020,
#  'talk •': 352652,
#  '• contribs': 425578,
#  'contribs •': 123002,
#  '• )': 425553,
#  'unspecified source': 391547,
#  'source for': 338265,
#  'i noticed': 194757,
#  'noticed that': 258692,
#  'the file': 362692,
#  "file '": 160924,
#  's description': 317932,
#  'page currently': 279892,
#  'currently doesn': 128937,
#  "doesn '": 141170,
#  't specify': 351248,
#  'specify who': 340008,
#  'who created': 408572,
#  'created the': 126850,
#  'the content': 361252,
#  'content ,': 122236,
#  ', so': 17197,
#  'so the': 334723,
#  'the copyright': 361331,
#  'copyright status': 124332,
#  'status is': 343077,
#  'is unclear': 210615,
#  'unclear .': 389475,
#  'you did': 419585,
#  'did not': 136456,
#  'not create': 256323,
#  'create this': 126756,
#  'this file': 374702,
#  'file yourself': 160983,
#  'yourself ,': 423145,
#  ', then': 17585,
#  'then you': 371459,
#  'will need': 411799,
#  'need to': 251008,
#  'to specify': 382311,
#  'specify the': 340003,
#  'the owner': 365775,
#  'owner of': 279433,
#  'of the': 266612,
#  'copyright .': 124262,
#  'you obtained': 420254,
#  'obtained it': 260740,
#  'it from': 212032,
#  'from a': 169099,
#  'a website': 48630,
#  'website ,': 404045,
#  'then a': 370993,
#  'a link': 45878,
#  'link to': 226733,
#  'the website': 369204,
#  'website from': 404081,
#  'from which': 170068,
#  'which it': 407586,
#  'it was': 212759,
#  'was taken': 402397,
#  'taken ,': 352186,
#  ', together': 17663,
#  'together with': 383147,
#  'with a': 412730,
#  'a restatement': 47286,
#  'restatement of': 312261,
#  'of that': 266611,
#  'that website': 358845,
#  "website '": 404042,
#  's terms': 319510,
#  'terms of': 354803,
#  'of use': 266860,
#  'use of': 393386,
#  'of its': 264216,
#  'its content': 213132,
#  ', is': 15023,
#  'is usually': 210721,
#  ...}

# %% [markdown]
# # Method to calculate the avg of TFIDF (Naives Bayes Model)

# %%
def pr(y_i, y):
    p = train_term_doc[y==y_i].sum(0)
    return (p+1) / ((y==y_i).sum()+1)

# %% [markdown]
# # Method to get trainning model

# %%
def get_mdl(y):
    
    # y_train
    y = y.values
    
    # pr(1,y): calculate te avg of TFIDF of toxic sentences
    # pr(0,y): calculate te avg of TFIDF of nontoxic sentences
    # get log helps to increase the weight of the word appears in toxic sentence
    r = np.log(pr(1,y) / pr(0,y))
    
    # initilize Logistic Regression
    m = LogisticRegression(C=4, dual=True, solver='liblinear')
    
    # get the X_train
    x_nb = train_term_doc.multiply(r)
    
    # return training model from X_train and y_train
    # also return the weight of the word appreas in toxic sentence too
    return m.fit(x_nb, y), r

# %% [markdown]
# # Create an probability array of the sample for each class in the model.

# %%
# label_cols = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
preds = np.zeros((len(test), len(label_cols)))

# %% [markdown]
# # Returns the probability of the sample for each class in the model.

# %%
# i represents for the index
# j represent for the column (class) we are using to calculate
for i, j in enumerate(label_cols):
    
    # get training model and weight from get_mdl method
    m,r = get_mdl(train[j])
    
    # transfering to the probability array by predict_proba method from Logistic Regression 
    
    # we would like to get the predicted probabilities for the positive label only 
    
    # that's why we use logistic_model.predict_proba(data)[:,1]
    
    preds[:,i] = m.predict_proba(test_term_doc.multiply(r))[:,1]
# Out:
# /Users/kevinngo/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/kevinngo/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/kevinngo/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/kevinngo/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/kevinngo/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %% [markdown]
# # Extract data from preds array to actual submission.csv to test in Kaggle

# %%
subm = pd.read_csv('Files/sample_submission.csv')
sub = pd.DataFrame({'id': subm['id']})
submission = pd.concat([sub, pd.DataFrame(preds, columns = label_cols)], axis=1)
submission.to_csv('submission.csv', index=False)

# %% [markdown]
# # Calculate mean_absolute_error between the actual (test) label and the pred_lable by using two ways: MAE (Mean Absolute Error) and RMSE (Root Mean Square Error)

# %%
from sklearn import metrics

actual_label = pd.read_csv('Files/test_labels.csv')
pred_label = pd.read_csv('submission.csv')

actual_label[label_cols] = actual_label[label_cols].replace(-1, 1)

print("MAE: ")
for col in label_cols:
    actual = actual_label[col].values
    pred = pred_label[col].values
    print(col, metrics.mean_absolute_error(actual, pred))
    
from sklearn import metrics
import numpy as np

print("\nRMSE")
for col in label_cols:
    actual = actual_label[col].values
    pred = pred_label[col].values
    print(col, np.sqrt(metrics.mean_squared_error(actual, pred)))
# Out:
# MAE:
# toxic 0.47286738472184975
# severe_toxic 0.5767147192523256
# obscene 0.5136402669890279
# threat 0.5821299790243356
# insult 0.5389356486819584
# identity_hate 0.5789006890911239
#
# RMSE
# toxic 0.6605789476649551
# severe_toxic 0.7553369891125109
# obscene 0.7009065074997879
# threat 0.7623409231058985
# insult 0.7163783359083947
# identity_hate 0.7577892207453808
