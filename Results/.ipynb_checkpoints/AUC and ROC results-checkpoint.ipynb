# %% [markdown]
# # This file will calculate AUC and ROC of 9 methods:
#
# 1. **OHE Logistic Regression**
# 1. **OHE Randomforest**
# 1. **TFIDF Logistic Regression**
# 1. **Word2vec Decision Tree**
# 1. **Word2vec Logistic Regression**
# 1. **Word2vec Randomforest**
# 1. **MultinomialDB**
# 1. **Decision Tree (DT) using countvectorizer**
# 1. **Random Forest (RF) using countvectorizer**
#
# ### with 153165 test samples

# %%
import pandas as pd
import numpy as np

# Importing the "pyplot" package of "matplotlib" library of python to generate 
# graphs and plot curves:
import matplotlib.pyplot as plt


label_cols = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']

test_labels = pd.read_csv('test_labels.csv')
test_labels[label_cols] = test_labels[label_cols].replace(-1, 1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

OHELogReg_Labels = pd.read_csv('OHE_LogReg_submission.csv')
OHERandomforest_Labels = pd.read_csv('OHE_Randomforest_submission.csv')
TFIDFLogReg_Labels = pd.read_csv('TFIDF_LogReg_submission.csv')
W2VDectree_Labels = pd.read_csv('Word2vec_DecTree_submission.csv')
W2VLogReg_Labels = pd.read_csv('Word2vec_LogisticReg_submission.csv')
W2VRandomForest_Labels = pd.read_csv('Word2vec_Randomforest_submission.csv')
MultinomialDB_Labels = pd.read_csv('MultinomialDB_submission.csv')
DT_Labels = pd.read_csv('DT_submission.csv')
RF_Labels = pd.read_csv('RF_submission.csv')


for col in label_cols:
    print("\n**", col, "**: ")
    y_test = test_labels[col]
    
    # y_prediction    
    y_pred_OHELogReg = OHELogReg_Labels[col]
    y_pred_OHERandomforest = OHERandomforest_Labels[col]
    y_pred_TFIDFLogReg = TFIDFLogReg_Labels[col]
    y_pred_W2VDectree = W2VDectree_Labels[col]
    y_pred_W2VLogReg = W2VLogReg_Labels[col]
    y_pred_W2VRandomForest = W2VRandomForest_Labels[col]
    y_pred_MultinomialDB = MultinomialDB_Labels[col]
    y_pred_DT = DT_Labels[col]
    y_pred_RF = RF_Labels[col]
    
    
    # OHELogReg AUC    
    fprOHELogReg, tprOHELogReg, thresholdsOHELogReg = metrics.roc_curve(y_test, y_pred_OHELogReg, pos_label=1)
    AUCOHELogReg = metrics.auc(fprOHELogReg, tprOHELogReg)
    print("OHELogReg - AUC: ", AUCOHELogReg)
    
    # OHERandomforest AUC
    fprOHERandomforest, tprOHERandomforest, thresholdsOHERandomforest = metrics.roc_curve(y_test, y_pred_OHERandomforest, pos_label=1)
    AUCOHERandomforest = metrics.auc(fprOHERandomforest, tprOHERandomforest)
    print("OHERandomforest - AUC: ", AUCOHERandomforest)
    
    # OHELogRegTFIDFLogReg AUC
    fprTFIDFLogReg, tprTFIDFLogReg, thresholdsTFIDFLogReg = metrics.roc_curve(y_test, y_pred_TFIDFLogReg, pos_label=1)
    AUCTFIDFLogReg = metrics.auc(fprTFIDFLogReg, tprTFIDFLogReg)
    print("TFIDFLogReg - AUC: ", AUCTFIDFLogReg)
    
    # W2VDectree AUC
    fprW2VDectree, tprW2VDectree, thresholdsW2VDectree = metrics.roc_curve(y_test, y_pred_W2VDectree, pos_label=1)
    AUCW2VDectree = metrics.auc(fprW2VDectree, tprW2VDectree)
    print("W2VDectree - AUC: ", AUCW2VDectree)
    
    # W2VLogReg AUC
    fprW2VLogReg, tprW2VLogReg, thresholdsW2VLogReg = metrics.roc_curve(y_test, y_pred_W2VLogReg, pos_label=1)
    AUCW2VLogReg = metrics.auc(fprW2VLogReg, tprW2VLogReg)
    print("W2VLogReg - AUC: ", AUCW2VLogReg)
    
    # W2VRandomForest AUC     
    fprW2VRandomForest, tprW2VRandomForest, thresholdsW2VRandomForest = metrics.roc_curve(y_test, y_pred_W2VRandomForest, pos_label=1)
    AUCW2VRandomForest = metrics.auc(fprW2VRandomForest, tprW2VRandomForest)
    print("W2VRandomForest - AUC: ", AUCW2VRandomForest)
    
    # MultinomialDB AUC     
    fprMultinomialDB, tprMultinomialDB, thresholdsMultinomialDB = metrics.roc_curve(y_test, y_pred_MultinomialDB, pos_label=1)
    AUCMultinomialDB = metrics.auc(fprMultinomialDB, tprMultinomialDB)
    print("MultinomialDB - AUC: ", AUCMultinomialDB)
    
    # DT AUC     
    fprDT, tprDT, thresholdsDT = metrics.roc_curve(y_test, y_pred_DT, pos_label=1)
    AUCDT = metrics.auc(fprDT, tprDT)
    print("DT - AUC: ", AUCDT)

    # RF AUC     
    fprRF, tprRF, thresholdsRF = metrics.roc_curve(y_test, y_pred_RF, pos_label=1)
    AUCRF = metrics.auc(fprRF, tprRF)
    print("RF - AUC: ", AUCRF)
    
    # Drawing plot for each class (label) for all 6 methods     
    # %matplotlib inline
    plt.figure()
    
    plt.plot(fprOHELogReg, tprOHELogReg, color='yellow', lw=2, 
             label='ROC Curve OHELogReg (area = %0.2f)' % AUCOHELogReg)
    
    plt.plot(fprOHERandomforest, tprOHERandomforest, color='purple', lw=2, 
             label='ROC Curve OHERandomforest (area = %0.2f)' % AUCOHERandomforest)
    
    plt.plot(fprTFIDFLogReg, tprTFIDFLogReg, color='blue', lw=2, 
             label='ROC Curve TFIDFLogReg (area = %0.2f)' % AUCTFIDFLogReg)
    
    plt.plot(fprW2VDectree, tprW2VDectree, color='magenta', lw=2, 
             label='ROC Curve W2VDectree (area = %0.2f)' % AUCW2VDectree)
    
    plt.plot(fprW2VLogReg, tprW2VLogReg, color='red', lw=2, 
             label='ROC Curve W2VLogReg (area = %0.2f)' % AUCW2VLogReg)
    
    plt.plot(fprW2VRandomForest, tprW2VRandomForest, color='cyan', lw=2, 
             label='ROC Curve W2VRandomForest (area = %0.2f)' % AUCW2VRandomForest)
    
    plt.plot(fprMultinomialDB, tprMultinomialDB, color='green', lw=2, 
         label='ROC Curve MultinomialDB (area = %0.2f)' % AUCMultinomialDB)

    plt.plot(fprDT, tprDT, color='brown', lw=2, 
         label='ROC Curve DT (area = %0.2f)' % AUCDT)
    
    plt.plot(fprRF, tprRF, color='orange', lw=2, 
         label='ROC Curve RF (area = %0.2f)' % AUCRF)
    
    # Random Guess line:
    plt.plot([0, 1], [0, 1], color='black', lw=1, linestyle='--')

    # Defining The Range of X-Axis and Y-Axis:
    plt.xlim([-0.005, 1.005])
    plt.ylim([0.0, 1.01])

    # Labels, Title, Legend:
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")

    plt.show()
# Out:
# ** toxic **:
# OHELogReg - AUC:  0.4983229403112777
# OHERandomforest - AUC:  0.5003678111541748
# TFIDFLogReg - AUC:  0.6384902562278348
# W2VDectree - AUC:  0.5618430544784139
# W2VLogReg - AUC:  0.6250574701047176
# W2VRandomForest - AUC:  0.6135813039175748
# MultinomialDB - AUC:  0.6218241562173761
# DT - AUC:  0.6054579966228167
# RF - AUC:  0.634054070440889
# ** severe_toxic **:
# OHELogReg - AUC:  0.4995050709484982
# OHERandomforest - AUC:  0.4993767180428098
# TFIDFLogReg - AUC:  0.5671792498590328
# W2VDectree - AUC:  0.5084389366991837
# W2VLogReg - AUC:  0.5636316321554463
# W2VRandomForest - AUC:  0.5390336898411849
# MultinomialDB - AUC:  0.5494959200420434
# DT - AUC:  0.5100133313306425
# RF - AUC:  0.548740792454717
# ** obscene **:
# OHELogReg - AUC:  0.49758876473926594
# OHERandomforest - AUC:  0.49937086273486603
# TFIDFLogReg - AUC:  0.6152618817493236
# W2VDectree - AUC:  0.5415009945021105
# W2VLogReg - AUC:  0.6042146549605004
# W2VRandomForest - AUC:  0.5893542486377933
# MultinomialDB - AUC:  0.5957038581071662
# DT - AUC:  0.5764801907461852
# RF - AUC:  0.6074543574640295
# ** threat **:
# OHELogReg - AUC:  0.4990139969125965
# OHERandomforest - AUC:  0.5005959847760356
# TFIDFLogReg - AUC:  0.548361685493562
# W2VDectree - AUC:  0.5014144269746332
# W2VLogReg - AUC:  0.5425756927200591
# W2VRandomForest - AUC:  0.5138210783368428
# MultinomialDB - AUC:  0.5381228310491861
# DT - AUC:  0.5013125425781458
# RF - AUC:  0.5075991820843445
# ** insult **:
# OHELogReg - AUC:  0.49936869390196537
# OHERandomforest - AUC:  0.5010163226359075
# TFIDFLogReg - AUC:  0.6084441425799486
# W2VDectree - AUC:  0.5363503847518089
# W2VLogReg - AUC:  0.5998331856215644
# W2VRandomForest - AUC:  0.5860308618496908
# MultinomialDB - AUC:  0.589464049638447
# DT - AUC:  0.5554785810589916
# RF - AUC:  0.6031469944498543
# ** identity_hate **:
# OHELogReg - AUC:  0.4992055449788513
# OHERandomforest - AUC:  0.49888295320104453
# TFIDFLogReg - AUC:  0.5666844759913034
# W2VDectree - AUC:  0.5061955458215223
# W2VLogReg - AUC:  0.5596552713658064
# W2VRandomForest - AUC:  0.5384669890370989
# MultinomialDB - AUC:  0.5489479684896215
# DT - AUC:  0.5067022475628862
# RF - AUC:  0.5315187549721829
